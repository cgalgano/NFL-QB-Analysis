# %%
# Import required libraries
import sqlite3
import pandas as pd

# Connect to the SQLite database
db_path = "../nfl_qb_data.db"
conn = sqlite3.connect(db_path)

# %%
# Query the play_by_play table
query = "SELECT * FROM play_by_play LIMIT 5;"
play_by_play_sample = pd.read_sql_query(query, conn)
print("Sample data from play_by_play table:")
print(play_by_play_sample)
# Out:
# Sample data from play_by_play table:
# Empty DataFrame
# Columns: [game_id, play_id, player_id, team, play_type, yards_gained]
# Index: []

# %%
# Query the player_statistics table
query = "SELECT * FROM player_statistics LIMIT 5;"
player_statistics_sample = pd.read_sql_query(query, conn)
print("Sample data from player_statistics table:")
print(player_statistics_sample)
# Out:
# Sample data from player_statistics table:
# Empty DataFrame
# Columns: [player_id, season, team, stat_category, value]
# Index: []

# %%
# Query the next_gen_stats table
query = "SELECT * FROM next_gen_stats LIMIT 5;"
next_gen_stats_sample = pd.read_sql_query(query, conn)
print("Sample data from next_gen_stats table:")
print(next_gen_stats_sample)
# Out:
# Sample data from next_gen_stats table:
# Empty DataFrame
# Columns: [player_id, season, metric, value]
# Index: []

# %%
# Query the player_contracts table
query = "SELECT * FROM player_contracts LIMIT 5;"
player_contracts_sample = pd.read_sql_query(query, conn)
print("Sample data from player_contracts table:")
print(player_contracts_sample)
# Out:
# Sample data from player_contracts table:
# Empty DataFrame
# Columns: [player_id, team, contract_year, salary]
# Index: []

# %%
# Close the database connection
conn.close()
